# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\hp\Downloads\StudentsPerformance (1).csv",encoding='unicode_escape')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# <p>There are 1000 students and 8 columns in the csv file</p>

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# <p>The mean and std are calculated for math score ,reading score and writing score columns as they are numerical data provided remaining are categorical data</p>

# %%
df.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# <h6>There are total 8 columns</h6>
# <p>Now checking for missing values</p>

# %%
df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
g = sns.countplot(x='math score', data = df, palette='bright')
plt.setp(g.get_xticklabels(), rotation=90) 
plt.show(g)

# %%
g = sns.countplot(x='reading score', data = df, palette='bright')
plt.setp(g.get_xticklabels(), rotation=90) 
plt.show(g)

# %%
g = sns.countplot(x='writing score', data = df, palette='bright')
plt.setp(g.get_xticklabels(), rotation=90) 
plt.show(g)

# %% [markdown]
# <p>There are no Missing data to be filled in any of the columns so we can proceed with exploratory analysis of the dataset</p>

# %% [markdown]
# <h3>Lets See the graph and relations between the various Categories</h3>

# %% [markdown]
# <h4>Plots between math scores,reading score,writing score and the gender,race,parent level of eductaion</h4>
# <p>Scatter plots are used to plot data points on a horizontal and a vertical axis in the attempt to show how much one variable is affected by another. Each row in the data table is represented by a marker whose position depends on its values in the columns set on the X and Y axes.
#
# </p>

# %%
sns.set_style('whitegrid')
g = sns.scatterplot(x = "math score", y = "gender",data=df)
g.set(xlabel="math score",ylabel="gender")
plt.title("Scatter plot for gender vs math score")
plt.show(g)

# %%
g = sns.barplot(x = "gender", y = "math score",data=df)
g.set(xlabel="gender",ylabel="math score")
plt.title("Bar plot for gender vs math score")
plt.show(g)

# %% [markdown]
# <p>This shows that male has achieved more confidence intervals with scatterplot glyphs</p>

# %%
g = sns.countplot(x = "gender",data=df)
g.set(xlabel="gender",ylabel="math score")
plt.title("Count plot for gender")
plt.show(g)

# %% [markdown]
# <p>There are more female when compared to male in the exxam</p>

# %%
g = sns.swarmplot(x = "gender", y = "math score",data=df)
g.set(xlabel="gender",ylabel="math score")
plt.title("Swarm plot for gender vs math score")
plt.show(g)

# %%
g = sns.violinplot(x = "gender", y = "math score",data=df)
g.set(xlabel="gender",ylabel="math score")
plt.title("Violin plot for gender vs math score")
plt.show(g)

# %%
g = sns.boxplot(x = "gender", y = "math score",data=df)
g.set(xlabel="gender",ylabel="math score")
plt.title("Box plot for gender vs math score")
plt.show(g)

# %% [markdown]
# <p>There are more outliers in female when compared to male,This can be solved by assigning the outliers with central tendancy values but which would result in false predictions.Boxplot is only help full in case of the finding the outliers and other ascpects of the data,but surely not useful to make any predictions over given data after resolving them</p>

# %% [markdown]
# <p>This gives us the exact picture that more number of male have secured better marks than female </p>

# %%
df[df['gender']=='female'].describe()
# Out:
#        math score  reading score  writing score
# count  518.000000     518.000000     518.000000
# mean    63.633205      72.608108      72.467181
# std     15.491453      14.378245      14.844842
# min      0.000000      17.000000      10.000000
# 25%     54.000000      63.250000      64.000000
# 50%     65.000000      73.000000      74.000000
# 75%     74.000000      83.000000      82.000000
# max    100.000000     100.000000     100.000000

# %%
df[df['gender']=='male'].describe()
# Out:
#        math score  reading score  writing score
# count  482.000000     482.000000     482.000000
# mean    68.728216      65.473029      63.311203
# std     14.356277      13.931832      14.113832
# min     27.000000      23.000000      15.000000
# 25%     59.000000      56.000000      53.000000
# 50%     69.000000      66.000000      64.000000
# 75%     79.000000      75.000000      73.750000
# max    100.000000     100.000000     100.000000

# %% [markdown]
# <p>In math score male have less std and more mean that means male are performing much better than female ,Also having better mean around which more number of students have achieved more marks</p>

# %%
sns.set_style('whitegrid')
g = sns.scatterplot(x = "reading score", y = "gender",data=df)
g.set(xlabel="math score",ylabel="gender")
plt.title("Scatter plot for gender vs reading score")
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.barplot(x = "gender", y = "reading score",data=df)
g.set(xlabel="reading score",ylabel="gender")
plt.title("Bar plot for gender vs reading score")
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.swarmplot(x = "gender", y = "reading score",data=df)
g.set(xlabel="reading score",ylabel="gender")
plt.title("swarm plot for gender vs reading score")
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.violinplot(x = "gender", y = "reading score",data=df)
g.set(xlabel="reading score",ylabel="gender")
plt.title("Violin plot for gender vs reading score")
plt.show(g)

# %% [markdown]
# <p>This surely shows that even though female have more mean but due to high std it shows that number of female secured marks in reading score are far from mean when compared to male</p>

# %%
sns.set_style('whitegrid')
g = sns.scatterplot(x = "writing score", y = "gender",data=df)
g.set(xlabel="writing score",ylabel="gender")
plt.title("Scatter plot for gender vs writing score")
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.barplot(x = "gender", y = "writing score",data=df)
g.set(xlabel="gender",ylabel="writing score")
plt.title("bar plot for gender vs writing score")
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.swarmplot(x = "gender", y = "writing score",data=df)
g.set(xlabel="gender",ylabel="writing score")
plt.title("swarm plot for gender vs writing score")
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.violinplot(x = "gender", y = "writing score",data=df)
g.set(xlabel="gender",ylabel="writing score")
plt.title("violin plot for gender vs writing score")
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.boxplot(x = "gender", y = "writing score",data=df)
g.set(xlabel="gender",ylabel="writing score")
plt.title("box plot for gender vs writing score")
plt.show(g)

# %% [markdown]
# <p>Clearly from above data visualizations and decriptions we can notice that in writing score female have more mean than that of male also they are performindg well as tendancy of people are more near to mean with outliers having less marks</p>

# %% [markdown]
# <p>So from above the conclusions are</p>
# <h5>There are more female who have taken test than that of male </h5>
# <h5>The performance of male is somewhat better in math score than female as
# the standard deviation is quite less than that of male ,even though having more mean</h5>
# <h5>The perfomance of male and female are quite same in writing and reading scores based on standard deviation ,But the in the clusttering near mean is less for female when compared to that of male</h5>

# %%
sns.set_style('whitegrid')
g = sns.scatterplot(x = "math score", y = "race/ethnicity",data=df)
g.set(xlabel="math score",ylabel="race/ethnicity")
plt.title("Scatter plot for race/ethnicity vs math score")
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.scatterplot(x = "race/ethnicity", y = "math score",data=df)
g.set(xlabel="race/ethnicity",ylabel="math score")
plt.title("scatter plot for race/ethnicity vs math score")
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.barplot(x = "race/ethnicity", y = "math score",data=df)
g.set(xlabel="race/ethnicity",ylabel="math score")
plt.title("bar plot for race/ethnicity vs math score")
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.swarmplot(x = "race/ethnicity", y = "math score",data=df)
g.set(xlabel="race/ethnicity",ylabel="math score")
plt.title("swarm plot for race/ethnicity  vs math score")
plt.show(g)

# %%
df[df['race/ethnicity']=='group A'].describe()
# Out:
#        math score  reading score  writing score
# count   89.000000      89.000000      89.000000
# mean    61.629213      64.674157      62.674157
# std     14.523008      15.543762      15.468278
# min     28.000000      23.000000      19.000000
# 25%     51.000000      53.000000      51.000000
# 50%     61.000000      64.000000      62.000000
# 75%     71.000000      74.000000      73.000000
# max    100.000000     100.000000      97.000000

# %%
df[df['race/ethnicity']=='group B'].describe()
# Out:
#        math score  reading score  writing score
# count  190.000000     190.000000     190.000000
# mean    63.452632      67.352632      65.600000
# std     15.468191      15.177499      15.625173
# min      8.000000      24.000000      15.000000
# 25%     54.000000      56.000000      55.250000
# 50%     63.000000      67.000000      67.000000
# 75%     74.000000      79.750000      78.000000
# max     97.000000      97.000000      96.000000

# %%
df[df['race/ethnicity']=='group C'].describe()
# Out:
#        math score  reading score  writing score
# count  319.000000     319.000000     319.000000
# mean    64.463950      69.103448      67.827586
# std     14.852666      13.997033      14.983378
# min      0.000000      17.000000      10.000000
# 25%     55.000000      60.000000      57.000000
# 50%     65.000000      71.000000      68.000000
# 75%     74.000000      78.500000      79.000000
# max     98.000000     100.000000     100.000000

# %%
df[df['race/ethnicity']=='group D'].describe()
# Out:
#        math score  reading score  writing score
# count  262.000000     262.000000     262.000000
# mean    67.362595      70.030534      70.145038
# std     13.769386      13.895306      14.367707
# min     26.000000      31.000000      32.000000
# 25%     59.000000      60.250000      61.000000
# 50%     69.000000      71.000000      72.000000
# 75%     77.000000      79.000000      80.000000
# max    100.000000     100.000000     100.000000

# %%
df[df['race/ethnicity']=='group E'].describe()
# Out:
#        math score  reading score  writing score
# count  140.000000     140.000000     140.000000
# mean    73.821429      73.028571      71.407143
# std     15.534259      14.874024      15.113906
# min     30.000000      26.000000      22.000000
# 25%     64.750000      63.000000      62.000000
# 50%     74.500000      74.000000      72.000000
# 75%     85.000000      84.000000      80.250000
# max    100.000000     100.000000     100.000000

# %% [markdown]
# <p>From above we can say that group D is second largest race in given data which is performing well when compared to other races as it has less std which means that number of participants in that race have marks very near to the mean rather than having more outliers</p>

# %%
p = sns.countplot(x='parental level of education', data = df, palette='bright')
_ = plt.setp(p.get_xticklabels(), rotation=90)

# %% [markdown]
# <h4>To make discussion on parental level of eductaion we will sum up the marks of the students who have taken test and compare with this to get better results</h4>

# %%
df['total'] = (df['math score']+df['reading score']+df['writing score'])

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  total
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229

# %%
df[df['total']==300]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 458  female        group E           bachelor's degree  standard
# 916    male        group E           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test preparation course  math score  reading score  writing score  total
# 458                    none         100            100            100    300
# 916               completed         100            100            100    300
# 962                    none         100            100            100    300

# %% [markdown]
# <p>From above we can see that the exam was conducted for 300 marks in total with considering all tests </p>

# %% [markdown]
# <p>For more understanding we will set a pass mark for each subject and we will know about which student has performed well and reason behind it when it comes to this case</p>

# %% [markdown]
# <p>Let pass mark be 35 for each test that has been conducted</p>
# <p>We will come to know does students belonging to educated families perform well in tests or not from this analysis</p>

# %%
df['math score pass'] = df['math score'] >= 35

# %%
df['reading score pass'] = df['reading score'] >= 35

# %%
df['writing score pass'] = df['writing score'] >= 35

# %%
df['total pass'] = df['total'] >= 35*3

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  total  \
# 0                    none          72             72             74    218
# 1               completed          69             90             88    247
# 2                    none          90             95             93    278
# 3                    none          47             57             44    148
# 4                    none          76             78             75    229
#
#    math score pass  reading score pass  writing score pass  total pass
# ...

# %%
(df['math score pass']==True).sum()
# Out:
# 978

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "parental level of education",data=df,hue = 'math score pass')
g.set(ylabel="count")
plt.title("count plot for parent level of education comparing it with pass status of math score")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %% [markdown]
# <p>Definitely we can say that parental education shows a great impact over the child's math studies as fail chances are very less for high educated parent's children</p>

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "parental level of education",data=df,hue = 'reading score pass')
g.set(ylabel="count")
plt.title("count plot for parent level of education comparing it with pass status of reading score")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %% [markdown]
# <p>Definitely we can say that parental education shows a great impact over the child's reading studies as fail chances are very less for high educated parent's children</p>

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "parental level of education",data=df,hue = 'writing score pass')
g.set(ylabel="count")
plt.title("count plot for parent level of education comparing it with pass status of writing score")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %% [markdown]
# <p>Definitely we can say that parental education shows a great impact over the child's writing studies as fail chances are very less for high educated parent's children</p>

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "parental level of education",data=df,hue = 'total pass')
g.set(ylabel="count")
plt.title("count plot for parent level of education comparing it with pass status of total score")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %% [markdown]
# <p>There is no doubt that the parental level of education will definitely show a great role in students pass/fail status</p>

# %% [markdown]
# <h4>Let's check whether it will be applicable to even gender ,racce/ethinicity.Also on the Lunch</h4>

# %% [markdown]
# <h5>Starting with gender</h5>

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "gender",data=df,hue = 'math score pass')
g.set(ylabel="count")
plt.title("count plot for gender comparing it with pass status of math score")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %% [markdown]
# <p>From the previous vizualization also we have concluded that more number of students in female dont fall near to the mean due to which we have also seen outliers in box plot ,whereas coming to male eventhough population is less they have less fail rate due to more people near to mean and having less standard deviation.So male perform well in math score pass with less failure rate</p>

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "gender",data=df,hue = 'reading score pass')
g.set(ylabel="count")
plt.title("count plot for gender comparing it with pass status of reading score")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "gender",data=df,hue = 'writing score pass')
g.set(ylabel="count")
plt.title("count plot for gender comparing it with pass status of writing score")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "gender",data=df,hue = 'total pass')
g.set(ylabel="count")
plt.title("count plot for gender comparing it with pass status of total pass")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %% [markdown]
# <p>The conclusions of the above remain same as previously discussed above withe the help of much plotting that we have used using seaborn for the role of gender</p>

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "race/ethnicity",data=df,hue = 'math score pass')
g.set(ylabel="count")
plt.title("count plot for race/ethnicity comparing it with pass status of math score")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "race/ethnicity",data=df,hue = 'reading score pass')
g.set(ylabel="count")
plt.title("count plot for race/ethnicity comparing it with pass status of reading score")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "race/ethnicity",data=df,hue = 'writing score pass')
g.set(ylabel="count")
plt.title("count plot for race/ethnicity comparing it with pass status of writing score")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "race/ethnicity",data=df,hue = 'total pass')
g.set(ylabel="count")
plt.title("count plot for race/ethnicity comparing it with pass status of total pass")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %% [markdown]
# <p>From the above race/ethnicity we can say that there is a unequal distribution of children.Eventhough in these circumstances the students belonging to group A and group E have performed very well with no failure rate.We can also say that race might play a role but now we will see those students whose parents level of education is less and belong to theser race.By this we can say really race plays a important role</p>

# %%
items = ["some college" ,"high school","some high school"]

# %%
df_temp = pd.DataFrame()

# %%
df_temp['total pass'] = df['total pass']

# %%
df_temp['race'] = df['race/ethnicity']

# %%
for ind in df.index:
    if df['parental level of education'][ind] in ["some college" ,"high school","some high school"]:
        df_temp['low_educated_pass'][ind] = True
    else:
        df_temp['low_educated_pass'][ind] = False
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\hp\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_temp.head()
# Out:
#    total pass     race  low_educated_pass
# 0        True  group B              False
# 1        True  group C               True
# 2        True  group B              False
# 3        True  group A              False
# 4        True  group C               True

# %%
df_temp = df_temp[df_temp['low_educated_pass']==True]

# %%
df_temp.head()
# Out:
#    total pass     race  low_educated_pass
# 1        True  group C               True
# 4        True  group C               True
# 6        True  group B               True
# 7        True  group B               True
# 8        True  group D               True

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "race",data=df_temp,hue = 'total pass')
g.set(ylabel="count")
plt.title("count plot for race/ethnicity comparing it with pass status of total pass")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %% [markdown]
# <p>By this we can say that race/ethnicity has some minimal role by observing on the group E in prev and present graphs as the value of failure rate increases when we sorted the parents whose education is less</p>

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "lunch",data=df,hue = 'total pass')
g.set(ylabel="count")
plt.title("count plot for lunch comparing it with pass status of total pass")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %%
sns.set_style('whitegrid')
g = sns.countplot(x = "lunch",data=df,hue = 'math score pass')
g.set(ylabel="count")
plt.title("count plot for lunch comparing it with pass status of math score pass")
plt.setp(g.get_xticklabels(),rotation=90)
plt.show(g)

# %%
(df['lunch']=='standard').sum()
# Out:
# 645

# %%
df.shape
# Out:
# (1000, 13)

# %% [markdown]
# <p>Standard --> 645</p>
# <p>free/reduced -->355</p>
